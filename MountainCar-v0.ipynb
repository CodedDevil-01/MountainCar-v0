# %%
import gym 
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
environment_name = "MountainCar-v0"
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()

# %%
env.action_space.sample()
# Out:
# 0

# %%
env.observation_space.sample()
# Out:
# array([0.09966112, 0.05984768], dtype=float32)

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose = 1)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=100000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 953  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 641          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0006931245 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -6.76e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.7         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000107    |
# |    value_loss           | 135          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 600          |
# |    iterations           | 3            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0052458895 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.00126     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.6         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000961    |
# |    value_loss           | 89.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008496912 |
# |    clip_fraction        | 0.0122      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.00143    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0015     |
# |    value_loss           | 90.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 577         |
# |    iterations           | 5           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005177214 |
# |    clip_fraction        | 0.004       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.00174    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.9        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.000245    |
# |    value_loss           | 88          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 573          |
# |    iterations           | 6            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0005502503 |
# |    clip_fraction        | 0.0238       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.000923     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.6         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 93.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 7           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011021411 |
# |    clip_fraction        | 0.0358      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -3.85e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.6        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000817   |
# |    value_loss           | 97.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 565          |
# |    iterations           | 8            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0043908255 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.000189     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 85.3         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | 0.000475     |
# |    value_loss           | 110          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 9           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009323651 |
# |    clip_fraction        | 0.0419      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.987      |
# |    explained_variance   | -0.00067    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.2        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.000938   |
# |    value_loss           | 121         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 557          |
# |    iterations           | 10           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0046816394 |
# |    clip_fraction        | 0.0617       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.897       |
# |    explained_variance   | -0.000211    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.3         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000552    |
# |    value_loss           | 142          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 553        |
# |    iterations           | 11         |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01145451 |
# |    clip_fraction        | 0.042      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.882     |
# |    explained_variance   | -6.85e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 63.4       |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.000406  |
# |    value_loss           | 140        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 549         |
# |    iterations           | 12          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007096272 |
# |    clip_fraction        | 0.0327      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.787      |
# |    explained_variance   | -4.26e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 78.9        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.000222    |
# |    value_loss           | 148         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 544           |
# |    iterations           | 13            |
# |    time_elapsed         | 48            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00076870795 |
# |    clip_fraction        | 0.0117        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.725        |
# |    explained_variance   | -4.72e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 65.4          |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000251     |
# |    value_loss           | 155           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 541          |
# |    iterations           | 14           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0026922356 |
# |    clip_fraction        | 0.0224       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.819       |
# |    explained_variance   | -6.12e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 162          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000946    |
# |    value_loss           | 173          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 541         |
# |    iterations           | 15          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008229824 |
# |    clip_fraction        | 0.0997      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.732      |
# |    explained_variance   | -1.57e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 89.3        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00298    |
# |    value_loss           | 161         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 541         |
# |    iterations           | 16          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.002798081 |
# |    clip_fraction        | 0.0236      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.761      |
# |    explained_variance   | -2.53e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.3        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.000839   |
# |    value_loss           | 165         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 541         |
# |    iterations           | 17          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.002557176 |
# |    clip_fraction        | 0.0191      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.774      |
# |    explained_variance   | -1.67e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 116         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00141    |
# |    value_loss           | 167         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 541        |
# |    iterations           | 18         |
# |    time_elapsed         | 68         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00716133 |
# |    clip_fraction        | 0.0175     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.764     |
# |    explained_variance   | -1.19e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 83.7       |
# |    n_updates            | 170        |
# |    policy_gradient_loss | 9.54e-05   |
# |    value_loss           | 183        |
# ----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 542           |
# |    iterations           | 19            |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00045693896 |
# |    clip_fraction        | 0.00103       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.677        |
# |    explained_variance   | -1.67e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 96.4          |
# |    n_updates            | 180           |
# |    policy_gradient_loss | 0.000203      |
# |    value_loss           | 169           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 542          |
# |    iterations           | 20           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0040804846 |
# |    clip_fraction        | 0.0134       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.709       |
# |    explained_variance   | -5.01e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 137          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000596    |
# |    value_loss           | 171          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 542         |
# |    iterations           | 21          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.004056004 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | -5.25e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.2        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00182    |
# |    value_loss           | 172         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 542          |
# |    iterations           | 22           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0036646992 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.647       |
# |    explained_variance   | -1.19e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 118          |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00016     |
# |    value_loss           | 187          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 23           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0009288797 |
# |    clip_fraction        | 0.0149       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.548       |
# |    explained_variance   | -7.15e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 106          |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000488    |
# |    value_loss           | 171          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 24           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0027335333 |
# |    clip_fraction        | 0.0136       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.483       |
# |    explained_variance   | -4.29e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 171          |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00023     |
# |    value_loss           | 171          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 543           |
# |    iterations           | 25            |
# |    time_elapsed         | 94            |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.00096343644 |
# |    clip_fraction        | 0.00884       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.465        |
# |    explained_variance   | -1.79e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 90.5          |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.000189     |
# |    value_loss           | 173           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 544          |
# |    iterations           | 26           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0030901977 |
# |    clip_fraction        | 0.027        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.428       |
# |    explained_variance   | -3.34e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 96.3         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000935    |
# |    value_loss           | 188          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 544          |
# |    iterations           | 27           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0011077351 |
# |    clip_fraction        | 0.0223       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.388       |
# |    explained_variance   | -3.58e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 59.4         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | 0.000268     |
# |    value_loss           | 172          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 542          |
# |    iterations           | 28           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0017034864 |
# |    clip_fraction        | 0.0136       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.399       |
# |    explained_variance   | -1.79e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 160          |
# |    n_updates            | 270          |
# |    policy_gradient_loss | 0.00034      |
# |    value_loss           | 174          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 541          |
# |    iterations           | 29           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0022436592 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.369       |
# |    explained_variance   | -1.91e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 66.8         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000191    |
# |    value_loss           | 174          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 539          |
# |    iterations           | 30           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0010006024 |
# |    clip_fraction        | 0.00723      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.347       |
# |    explained_variance   | -1.79e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 182          |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -6.14e-05    |
# |    value_loss           | 176          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 538          |
# |    iterations           | 31           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0004922274 |
# |    clip_fraction        | 0.00991      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.333       |
# |    explained_variance   | -1.67e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 74.7         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 0.000239     |
# |    value_loss           | 186          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 537          |
# |    iterations           | 32           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0009536998 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.32        |
# |    explained_variance   | -9.54e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.2         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000121    |
# |    value_loss           | 176          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 536          |
# |    iterations           | 33           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0002683523 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.33        |
# |    explained_variance   | -5.96e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.9         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000891    |
# |    value_loss           | 176          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 536         |
# |    iterations           | 34          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.002482599 |
# |    clip_fraction        | 0.0165      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.319      |
# |    explained_variance   | -1.07e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.9        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.000311    |
# |    value_loss           | 176         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 536           |
# |    iterations           | 35            |
# |    time_elapsed         | 133           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 0.00021662368 |
# |    clip_fraction        | 0.0114        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.252        |
# |    explained_variance   | -5.96e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 98.4          |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.000551     |
# |    value_loss           | 191           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 536           |
# |    iterations           | 36            |
# |    time_elapsed         | 137           |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 0.00018173765 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.261        |
# |    explained_variance   | -7.15e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 51.7          |
# |    n_updates            | 350           |
# |    policy_gradient_loss | 7.82e-06      |
# |    value_loss           | 175           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 537          |
# |    iterations           | 37           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0027894967 |
# |    clip_fraction        | 0.0177       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.304       |
# |    explained_variance   | -5.96e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 85.3         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000507    |
# |    value_loss           | 175          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 536           |
# |    iterations           | 38            |
# |    time_elapsed         | 144           |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 0.00028240425 |
# |    clip_fraction        | 0.00259       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.312        |
# |    explained_variance   | -4.77e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 64.4          |
# |    n_updates            | 370           |
# |    policy_gradient_loss | 0.000213      |
# |    value_loss           | 176           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 537           |
# |    iterations           | 39            |
# |    time_elapsed         | 148           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.00061791204 |
# |    clip_fraction        | 0.0101        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.263        |
# |    explained_variance   | -5.96e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 54.9          |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000124     |
# |    value_loss           | 191           |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 536         |
# |    iterations           | 40          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.001156239 |
# |    clip_fraction        | 0.00161     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.248      |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 84.9        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.000159    |
# |    value_loss           | 174         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 537           |
# |    iterations           | 41            |
# |    time_elapsed         | 156           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 0.00023162676 |
# |    clip_fraction        | 0.0084        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.209        |
# |    explained_variance   | -4.77e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 22.7          |
# |    n_updates            | 400           |
# |    policy_gradient_loss | 0.000141      |
# |    value_loss           | 176           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 537           |
# |    iterations           | 42            |
# |    time_elapsed         | 160           |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 0.00023829972 |
# |    clip_fraction        | 0.00337       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.201        |
# |    explained_variance   | -3.58e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 68.6          |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000136     |
# |    value_loss           | 176           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 537          |
# |    iterations           | 43           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0005335512 |
# |    clip_fraction        | 0.00166      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.19        |
# |    explained_variance   | -5.96e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 106          |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000106    |
# |    value_loss           | 190          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 537          |
# |    iterations           | 44           |
# |    time_elapsed         | 167          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0001797911 |
# |    clip_fraction        | 0.00439      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.172       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 136          |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000113    |
# |    value_loss           | 174          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 538           |
# |    iterations           | 45            |
# |    time_elapsed         | 171           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 0.00019306064 |
# |    clip_fraction        | 0.0112        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.203        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 59.7          |
# |    n_updates            | 440           |
# |    policy_gradient_loss | 0.000298      |
# |    value_loss           | 174           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 538           |
# |    iterations           | 46            |
# |    time_elapsed         | 175           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 0.00062952715 |
# |    clip_fraction        | 0.00469       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.177        |
# |    explained_variance   | -3.58e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 96.4          |
# |    n_updates            | 450           |
# |    policy_gradient_loss | 0.000144      |
# |    value_loss           | 175           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 538          |
# |    iterations           | 47           |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0016490645 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.193       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 109          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00047     |
# |    value_loss           | 189          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 538         |
# |    iterations           | 48          |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.000822608 |
# |    clip_fraction        | 0.00762     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.17       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 75.4        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.000193   |
# |    value_loss           | 173         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 538          |
# |    iterations           | 49           |
# |    time_elapsed         | 186          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0006486347 |
# |    clip_fraction        | 0.00713      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.152       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 78.8         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000425    |
# |    value_loss           | 173          |
# ------------------------------------------

# %%
PPO_path = os.path.join('Training', 'Saved Models', 'DQN_model')

# %%
model.save(PPO_path)

# %%
del model

# %%
model = PPO.load('Training/Saved Models/DQN_model', env=env)

# %%
from stable_baselines3.common.evaluation import evaluate_policy
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# C:\Users\Rajadurai\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (-200.0, 0.0)

# %%
env.close()

# %%
import gym 
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

environment_name = "MountainCar-v0"
env = gym.make(environment_name)

model = PPO.load('Training/Saved Models/DQN_model', env=env)

from stable_baselines3.common.evaluation import evaluate_policy
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# (-200.0, 0.0)

# %%
env.close()
